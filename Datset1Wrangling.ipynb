# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt

df = pd.read_csv('Student Attitude and Behavior.csv')
df
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 0                     No    Male        BCA       100.0        58.0
# 1                     No  Female        BCA        90.0        40.0
# 2                    Yes    Male        BCA       159.0        78.0
# 3                    Yes  Female        BCA       147.0        20.0
# 4                     No    Male        BCA       170.0        54.0
# ..                   ...     ...        ...         ...         ...
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 0         79.0       64.0          80.0    Video Games      0 - 30 minute
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    object
#  1   Gender                                                  235 non-null    object
#  2   Department                                              235 non-null    object
#  3   Height(CM)                                              235 non-null    float64
#  4   Weight(KG)                                              235 non-null    float64
#  5   10th Mark                                               235 non-null    float64
#  6   12th Mark                                               235 non-null    float64
#  7   college mark                                            235 non-null    float64
# ...

# %%
plt.scatter(df['10th Mark'],df['college mark'])

# %%
plt.scatter(df['12th Mark'],df['college mark'])

# %%
# Calculate the outliers
Q1 = df['Height(CM)'].quantile(0.25)
Q3 = df['Height(CM)'].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(upper_bound)
print(lower_bound)

outliers = df[(df['Height(CM)'] < lower_bound) | (df['Height(CM)'] > upper_bound)]
outliers
# Out:
# 197.0
# 125.0
#     Certification Course  Gender                     Department  Height(CM)  \
# 0                     No    Male                            BCA       100.0
# 1                     No  Female                            BCA        90.0
# 10                    No    Male                            BCA        99.0
# 19                   Yes  Female                            BCA       109.0
# 25                    No    Male                            BCA        90.0
# 29                    No  Female                            BCA        99.0
# 41                    No  Female                            BCA        98.0
# 47                    No    Male  B.com Accounting and Finance         90.0
# 55                    No    Male                       Commerce       100.0
# 67                   Yes    Male                            BCA       100.0
# 70                   Yes    Male                            BCA        99.0
# ...

# %%
plt.scatter(df[(df['Height(CM)'] > 125) & (df['Height(CM)'] < 197)]['Height(CM)'],
            df[(df['Height(CM)'] > 125) & (df['Height(CM)'] < 197)]['college mark'])

# %%
plt.scatter(df['Height(CM)'],df['college mark'])
plt.title('Scatter Plot of Height and college marks')
plt.xlabel('Height(CM)')
plt.ylabel('colllege mark')
# Out:
# Text(0, 0.5, 'colllege mark')

# %%
outliers.index
df.drop(outliers.index, inplace=True)

# %%
plt.scatter(df['Height(CM)'],df['college mark'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 218 entries, 2 to 234
# Data columns (total 19 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    218 non-null    object
#  1   Gender                                                  218 non-null    object
#  2   Department                                              218 non-null    object
#  3   Height(CM)                                              218 non-null    float64
#  4   Weight(KG)                                              218 non-null    float64
#  5   10th Mark                                               218 non-null    float64
#  6   12th Mark                                               218 non-null    float64
#  7   college mark                                            218 non-null    float64
# ...

# %%
plt.scatter(df['10th Mark'],df['college mark'])

# %%
plt.scatter(df['12th Mark'],df['college mark'])

# %%
plt.scatter(df['Weight(KG)'],df['college mark'])

# %%
df.drop(3, inplace=True)

# %%
plt.scatter(df['Weight(KG)'],df['college mark'])

# %%
Q1= df['Weight(KG)'].quantile(0.25)
Q3 = df['Weight(KG)'].quantile(0.75)

IQR = Q3 - Q1

lower_bound_Weight = Q1 - 1.5 * IQR
upper_bound_Weight = Q3 + 1.5 * IQR

print(upper_bound_Weight)
print(lower_bound_Weight)

outliers2 = df[(df['Weight(KG)'] < lower_bound_Weight) | (df['Weight(KG)'] > upper_bound_Weight)]
outliers2
# Out:
# 100.0
# 20.0
#     Certification Course Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 163                  Yes   Male   Commerce       190.0       106.0       82.0
#
#      12th Mark  college mark        hobbies daily studing time  \
# 163       78.0          80.0  Reading books         1 - 2 Hour
#
#     prefer to study in  salary expectation Do you like your degree?  \
# 163            Anytime               25000                      Yes
#
#     willingness to pursue a career based on their degree    \
# 163                                               100%
#
#     social medai & video Travelling Time  Stress Level  Financial Status  \
# 163        1 - 30 Minute    1.30 - 2 hour          Good              Bad
#
#     part-time job
# 163           Yes

# %%
df
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 2                    Yes    Male        BCA       159.0        78.0
# 4                     No    Male        BCA       170.0        54.0
# 5                    Yes  Female        BCA       139.0        33.0
# 6                    Yes    Male        BCA       165.0        50.0
# 7                     No    Male        BCA       152.0        43.0
# ..                   ...     ...        ...         ...         ...
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 2         71.0      61.00          55.0         Cinema         1 - 2 Hour
# ...

# %%
outliers3= df[df['salary expectation'] > 500000 ]

# %%
outliers3
# Out:
#     Certification Course Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 188                  Yes   Male  B.com ISM       170.0        80.0       67.0
#
#      12th Mark  college mark hobbies daily studing time prefer to study in  \
# 188       70.0          60.0  Sports   More Than 4 hour            Anytime
#
#      salary expectation Do you like your degree?  \
# 188              700000                      Yes
#
#     willingness to pursue a career based on their degree    \
# 188                                               100%
#
#     social medai & video Travelling Time  Stress Level  Financial Status  \
# 188        1 - 30 Minute   0 - 30 minutes          Good             good
#
#     part-time job
# 188            No

# %%
df.drop(188, inplace=True)

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  216.000000  216.000000  216.000000  216.000000    216.000000
# mean   162.166667   60.920833   76.839815   68.598750     70.639954
# std     11.807369   14.325787   13.248385   10.964798     16.090092
# min    130.000000   32.000000    7.400000   45.000000      1.000000
# 25%    153.750000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     71.650000
# 75%    170.000000   70.000000   86.125000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   92.000000    100.000000
#
#        salary expectation
# count          216.000000
# mean         23223.125000
# std          35706.021128
# min              0.000000
# 25%          15000.000000
# 50%          20000.000000
# 75%          25000.000000
# max         500000.000000

# %%
df.to_csv('Student Attitude and Behavior(Wrangled).csv')
